# %%
# import dependencies
import pandas as pd

# %%
# File path
file_path = 'resources/ticks.csv'

# Read in the data
df = pd.read_csv(file_path)

# Display the first 5 rows of the data
df.head(5)
# Out:
#          Date             Route Rating  \
# 0  2022-12-02        South Face    5.7
# 1  2022-11-22     Internal Scar   -5.9
# 2  2022-11-22     Italian Combo    5.9
# 3  2022-11-20      Elephant Man  -5.10
# 4  2022-11-20  Chocolate Corner    5.9
#
#                                                Notes  \
# 0  Lead all pitches with Nico (followed by Jake a...
# 1  SICKKKK CLIMB\r\n\r\nweird OW inside a chimney...
# 2  hung 2x. Feeling weak, is it the estrogen or t...
# 3                         sick route, felt gymnastic
# 4  First crack climb in 3 mo! Happy to be back :)...
#
#                                                  URL  Pitches  \
# 0  https://www.mountainproject.com/route/10571756...        3
# 1  https://www.mountainproject.com/route/10781756...        1
# 2  https://www.mountainproject.com/route/10878782...        1
# 3  https://www.mountainproject.com/route/10571766...        1
# 4  https://www.mountainproject.com/route/10571734...        1
#
# ...

# %%
df["Route Type"].value_counts()
# Out:
# Trad            50
# Sport           35
# Boulder         16
# Trad, TR         7
# Sport, TR        7
# Trad, Alpine     3
# Trad, Aid        2
# Trad, Sport      1
# TR               1
# Name: Route Type, dtype: int64

# %%
# Show top 5 locations climbed
df['Location'].value_counts().head(5)
# Out:
# California > San Francisco Bay Area > Castle Rock Area > Platypus                                                                        10
# California > San Francisco Bay Area > Castle Rock Area > Indian Rock                                                                      5
# California > San Francisco Bay Area > Castle Rock Area > California Ridge                                                                 5
# California > San Francisco Bay Area > Castle Rock Area > * Castle Rock Area Bouldering > Castle Rock Loop > Magoos > Mr Magoo Boulder     4
# California > Yosemite National Park > Yosemite Valley > Valley North Side > E. Yosemite Falls Area > Sunnyside Bench                      4
# Name: Location, dtype: int64

# %%
# View datatypes
df.dtypes
# Out:
# Date            object
# Route           object
# Rating          object
# Notes           object
# URL             object
# Pitches          int64
# Location        object
# Avg Stars      float64
# Your Stars       int64
# Style           object
# Lead Style      object
# Route Type      object
# Your Rating    float64
# Length         float64
# Rating Code      int64
# dtype: object

# %%
# View the routes and the number of times each route was performed
df['Route'].value_counts()
# Out:
# Plat-A-Pussy                   4
# Rat-A-Puss                     4
# South Face                     3
# Mullah                         3
# Viscious Circles               2
#                               ..
# Knob Job                       1
# Sweetie Pie (Dragon Scales)    1
# The Real Slam Dunk             1
# Unknown                        1
# Face Down at La Fonda          1
# Name: Route, Length: 100, dtype: int64

# %%
# Route type values
df['Route Type'].unique()
# Out:
# array(['Trad', 'Trad, Aid', 'Trad, TR', 'Sport', 'Trad, Sport', 'TR',
#        'Boulder', 'Sport, TR', 'Trad, Alpine'], dtype=object)

# %%
# View distribution of avg stars data
df['Avg Stars'].hist()

# %%
df.head(5)
# Out:
#          Date             Route Rating  \
# 0  2022-12-02        South Face    5.7
# 1  2022-11-22     Internal Scar   -5.9
# 2  2022-11-22     Italian Combo    5.9
# 3  2022-11-20      Elephant Man  -5.10
# 4  2022-11-20  Chocolate Corner    5.9
#
#                                                Notes  \
# 0  Lead all pitches with Nico (followed by Jake a...
# 1  SICKKKK CLIMB\r\n\r\nweird OW inside a chimney...
# 2  hung 2x. Feeling weak, is it the estrogen or t...
# 3                         sick route, felt gymnastic
# 4  First crack climb in 3 mo! Happy to be back :)...
#
#                                                  URL  Pitches  \
# 0  https://www.mountainproject.com/route/10571756...        3
# 1  https://www.mountainproject.com/route/10781756...        1
# 2  https://www.mountainproject.com/route/10878782...        1
# 3  https://www.mountainproject.com/route/10571766...        1
# 4  https://www.mountainproject.com/route/10571734...        1
#
# ...

# %%
# Find data where Rating Code is between 2000 and 3000
df.loc[(df['Rating Code'] >= 2000) & (df['Rating Code'] < 3000)]
# Out:
#            Date             Route Rating  \
# 1    2022-11-22     Internal Scar   -5.9
# 2    2022-11-22     Italian Combo    5.9
# 3    2022-11-20      Elephant Man  -5.10
# 4    2022-11-20  Chocolate Corner    5.9
# 5    2022-08-22       Jungle Book  -5.10
# ..          ...               ...    ...
# 116  2019-04-26      Plat-A-Pussy  5.10a
# 117  2019-04-19        Hand Crack    5.8
# 118  2019-04-19            Mullah  5.10a
# 120  2019-04-19   Blowing Bubbles  5.10a
# 121  2019-04-19   Blowing Bubbles  5.10a
#
#                                                  Notes  \
# 1    SICKKKK CLIMB\r\n\r\nweird OW inside a chimney...
# 2    hung 2x. Feeling weak, is it the estrogen or t...
# 3                           sick route, felt gymnastic
# 4    First crack climb in 3 mo! Happy to be back :)...
# 5    Approach really wasn&#39;t that bad.\r\n\r\nTo...
# ..                                                 ...
# 116                                                NaN
# ...

# %%
# Testing that branch is working
